# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('../data/test_image.jpg')
lane_image = np.copy(image)
gray = cv2.cvtColor(lane_image, cv2.COLOR_BGR2GRAY)

# %%
print(f'Before:\t{image.shape=}\t{gray.shape=}\t{lane_image.shape=}')
# image = cv2.resize(image, (int(image.shape[1] * .5), int(image.shape[0] * .5)))
# gray = cv2.resize(gray, (int(gray.shape[1] * .5), int(gray.shape[0] * .5)))
# print(f'After:\t{image.shape=}\t{gray.shape=}\t{lane_image.shape=}')
# Out:
# Before:	image.shape=(704, 1279, 3)	gray.shape=(704, 1279)	lane_image.shape=(704, 1279, 3)

# %%
plt.imshow(image)

# %%
plt.imshow(gray)

# %%
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
plt.imshow(blur)

# %%
canny = cv2.Canny(blur, 50, 150)

# %%
plt.imshow(canny)

# %%
def canny(image):
    _gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _blur = cv2.GaussianBlur(_gray, (5, 5), 0)
    canny = cv2.Canny(blur, 50, 150)
    del _gray, _blur
    return canny

# %%
def area_of_interest(image):
    height = image.shape[0]
    triangle = np.array([[(200, height), (1100, height), (550, 250)]])
    mask = np.zeros_like(image)
    cv2.fillPoly(mask, triangle, 255)
    del height, triangle
    return mask

# %%
plt.imshow(area_of_interest(image))
